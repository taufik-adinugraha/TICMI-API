# %%
from TicmiAPI import *

# %%
api = TICMIDataAPI(api_key='XXXXXXX')
date = "2024-06-19"
stock = "BBCA"

# %%
# Request data by date for a specific stock
data_by_date = api.request_data_by_date(date, stock)
data_by_date
# Out:
# {'public_expose': (401, 'Unauthorized\n'),
#  'trading_data': {'data': [{'Date': '2024-06-19',
#     'Open': 9250,
#     'High': 9250,
#     'Low': 9050,
#     'Close': 9050,
#     'Volume': 100051000,
#     'Value': 914391255000,
#     'Frequency': 26534,
#     'ChangePercent': -1.6304347826086956}],
#   'error': None,
#   'pagination': {}},
#  'stock_news': (401, 'Unauthorized\n')}

# %%
# Request index weight data
index_weight_data = api.request_index_weight(date, indexCode="LQ45")
index_weight_data
# Out:
# {'data': [{'Date': '2024-06-19',
#    'SecCode': 'BBCA',
#    'SharesForIndex': 30008605442,
#    'MarketCap': 271577879250100,
#    'Weight': 15.841509721607807},
#   {'Date': '2024-06-19',
#    'SecCode': 'BBRI',
#    'SharesForIndex': 52939709600,
#    'MarketCap': 217052809360000,
#    'Weight': 12.660987702949889},
#   {'Date': '2024-06-19',
#    'SecCode': 'BMRI',
#    'SharesForIndex': 36895319998,
#    'MarketCap': 212148089988500,
#    'Weight': 12.374888703208374},
#   {'Date': '2024-06-19',
#    'SecCode': 'AMMN',
#    'SharesForIndex': 12509392546,
#    'MarketCap': 150112710552000,
#    'Weight': 8.756280040601029},
#   {'Date': '2024-06-19',
#    'SecCode': 'TLKM',
#    'SharesForIndex': 47361645756,
#    'MarketCap': 134033457489480,
#    'Weight': 7.8183551830631},
#   {'Date': '2024-06-19',
#    'SecCode': 'ASII',
#    'SharesForIndex': 18254034111,
#    'MarketCap': 81230451793950,
#    'Weight': 4.738283527869398},
#   {'Date': '2024-06-19',
# ...

# %%
# Request static data for a specific stock
static_data = api.request_static_data(stock)
static_data
# Out:
# {'board_of_commissioners': (401, 'Unauthorized\n'),
#  'board_of_directors': (401, 'Unauthorized\n'),
#  'market_information': (401, 'Unauthorized\n'),
#  'company_profile': (401, 'Unauthorized\n'),
#  'company_address': (401, 'Unauthorized\n'),
#  'holding_composition': (401, 'Unauthorized\n')}
